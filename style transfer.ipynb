# %% [markdown]
# Import Dependencies and Pre-trained model

# %%
import tensorflow_hub as hub
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

# %% [markdown]
# Preprocess image and load

# %%
def load_image(img_path):
  img = tf.io.read_file(img_path)
  img = tf.image.decode_image(img, channels=3)
  img = tf.image.convert_image_dtype(img, tf.float32)
  img = img[tf.newaxis, :]
  return img

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ed92ea5a-de69-4af2-91ec-a80fbcb51a46" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed92ea5a-de69-4af2-91ec-a80fbcb51a46">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving art2.jpg to art2.jpg
# ...

# %%
content_image = load_image('/content/davika.jpg')
style_image = load_image('/content/art2.jpg')

# %% [markdown]
# Visualize Output

# %%
content_image.shape
# Out:
# TensorShape([1, 700, 500, 3])

# %%
plt.imshow(np.squeeze(content_image))
plt.show()

# %%
plt.imshow(np.squeeze(style_image))
plt.show()

# %%
stylized_image = model(tf.constant(content_image), tf.constant(style_image))[0]

# %%
plt.imshow(np.squeeze(stylized_image))
plt.show()

# %%
cv2.imwrite('hasil.jpg', cv2.cvtColor(np.squeeze(stylized_image)*255, cv2.COLOR_BGR2RGB))
# Out:
# True
